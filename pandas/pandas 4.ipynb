# %%
import pandas as pd
import numpy as np

bios = pd.read_csv('./data/bios.csv')
results = pd.read_parquet('./data/results.parquet')
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee['price'] = np.where(coffee['Coffee Type']=='Espresso',3.99,5.99)

# %%
#to get just first names
bios_new = bios.copy()
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux  \
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg
# 0               Gironde          FRA  France        NaN        NaN  \
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bios_new.query('first_name == "Keith"').head()
# Out:
#        athlete_id           name   born_date  born_city       born_region
# 1897         1907   Keith Hanlon  1966-09-01        NaN               NaN  \
# 3505         3517  Keith Wallace  1961-03-29    Preston           England
# 6228         6255  Keith Hartley  1940-10-15  Vancouver  British Columbia
# 8898         8946    Keith Mwila  1966-01-01        NaN               NaN
# 12053       12118   Keith Hervey  1898-11-03     Fulham           England
#
#       born_country            NOC  height_cm  weight_kg   died_date first_name
# 1897           NaN        Ireland        NaN        NaN         NaN      Keith
# 3505           GBR  Great Britain      165.0       51.0  1999-12-31      Keith
# 6228           CAN         Canada      200.0       85.0         NaN      Keith
# 8898           NaN         Zambia        NaN        NaN  1993-01-09      Keith
# 12053          GBR  Great Britain        NaN        NaN  1973-02-22      Keith

# %%
#to convert data type
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])
#you can deal with errors in this way
# bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'],errors='coerce')
#you can also specify a format
# bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'],format="%Y-%m-%d")
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux  \
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg
# 0               Gironde          FRA  France        NaN        NaN  \
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime
# 0  1960-10-02  Jean-François    1886-12-12
# 1         NaN         Arnaud    1969-04-01
# 2  1994-07-17           Jean    1898-08-13
# ...

# %%
#to check datatypes
# bios_new.info()
#using dataframe column you can easly create other date related columns
bios_new['born_year'] = bios_new['born_datetime'].dt.year
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux  \
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg
# 0               Gironde          FRA  France        NaN        NaN  \
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year
# 0  1960-10-02  Jean-François    1886-12-12     1886.0
# 1         NaN         Arnaud    1969-04-01     1969.0
# ...

# %%
bios_new['leap_year'] = bios_new['born_datetime'].dt.is_leap_year
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux  \
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg
# 0               Gironde          FRA  France        NaN        NaN  \
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year  leap_year
# 0  1960-10-02  Jean-François    1886-12-12     1886.0      False
# ...

# %%
#to save new dataframe
bios_new.to_csv('./data/bios_new.csv',index=False)

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x<165 else ('Average' if x<185 else 'Tall'))

# %%
def categorize_athlete(row):
  if row['height_cm'] < 175 and row['weight_kg'] < 70:
    return 'Lightweight'
  elif row['height_cm'] < 185 or row['weight_kg'] <= 80:
    return 'Middleweight'
  else:
    return 'Heavyweight'
  
bios['Category'] = bios.apply(categorize_athlete, axis=1)
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux  \
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg
# 0               Gironde          FRA  France        NaN        NaN  \
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year  leap_year
# 0  1960-10-02  Jean-François    1886-12-12     1886.0      False
# ...

# %%
bios = pd.read_csv('./data/bios.csv')
nocs = pd.read_csv('./data/noc_regions.csv')

# %%
#Merging & Concatenating Data
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios,nocs, left_on='born_country',right_on='NOC', how='left')
#with suffices specified
# bios_new = pd.merge(bios,nocs, left_on='born_country',right_on='NOC', how='left',suffixes=["bios","nocdf"])
bios_new.rename(columns={'region': 'born_country_full'},inplace=True)

# %%
bios_new[bios_new['born_country_full'].notna() & (bios_new['NOC_x'] != bios_new['born_country_full'])][['name','NOC_x','born_country_full']]
# Out:
#                        name                NOC_x born_country_full
# 4              Albert Canet               France                UK
# 16               Guy Forget               France           Morocco
# 37          Helen Aitchison        Great Britain                UK
# 38        Geraldine Beamish        Great Britain                UK
# 39             Dora Boothby        Great Britain                UK
# ...                     ...                  ...               ...
# 145488         Shakeel John  Trinidad and Tobago          Trinidad
# 145493   Landysh Falyakhova                  ROC            Russia
# 145495    Polina Luchnikova                  ROC            Russia
# 145496  Valeriya Merkusheva                  ROC            Russia
# 145497      Yuliya Smirnova                  ROC            Russia
#
# [38346 rows x 3 columns]

# %%
usa = bios[bios['born_country']=='USA'].copy()
gbr = bios[bios['born_country']=='GBR'].copy()
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region
# 4            5       Albert Canet  1878-04-17   Wandsworth     England  \
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country            NOC  height_cm  weight_kg   died_date
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN

# %%
new_df = pd.concat([usa,gbr])
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region
# 144811      148512  Benjamin Alexander  1983-05-08        London     England  \
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN

# %%
#merging on the same column name
combined_df = pd.merge(results, bios, on='athlete_id', how='left')

# %%
coffee.loc[[2,3], 'Units Sold'] = np.nan
#to check NaN values
coffee.info()
coffee.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   12 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 468.0+ bytes
# Day            0
# Coffee Type    0
# Units Sold     2
# dtype: int64

# %%
# to fill NaN values you can use mean value
coffee.fillna(coffee['Units Sold'].mean())
# you can use interpolate function to fill according to neghbour values
coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
#to drop rows with NaN
coffee.dropna()
#to drop rows with NaN in specific column
coffee.dropna(subset=['Units Sold'])
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
#to get rows with nan values in specific column
coffee[coffee['Units Sold'].isna()]
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
#aggregating data
bios['born_city'].value_counts()
bios[bios['born_country']=='USA']['born_city'].value_counts()
bios[bios['born_country']=='POL']['born_city'].value_counts()
bios[bios['born_country']=='POL']['born_region'].value_counts()
# Out:
# born_region
# Śląskie                427
# Małopolskie            389
# Mazowieckie            388
# Dolnośląskie           253
# Wielkopolskie          251
# Pomorskie              213
# Kujawsko-Pomorskie     181
# Łódzkie                158
# Zachodniopomorskie     121
# Warmińsko-Mazurskie    119
# Lubuskie               103
# Podkarpackie            94
# Lubelskie               83
# Opolskie                58
# Podlaskie               54
# Świętokrzyskie          50
# Name: count, dtype: int64

# %%
#groupby function
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
coffee.groupby(['Coffee Type'])['Units Sold'].mean()

coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'price':'mean'})
coffee.groupby(['Coffee Type','Day']).agg({'Units Sold': 'sum', 'price':'mean'})
# Out:
#                        Units Sold  price
# Coffee Type Day
# Espresso    Friday             45   3.99
#             Monday             25   3.99
#             Saturday           45   3.99
#             Sunday             45   3.99
#             Thursday           40   3.99
#             Tuesday            30   3.99
#             Wednesday          35   3.99
# Latte       Friday             35   5.99
#             Monday             15   5.99
#             Saturday           35   5.99
#             Sunday             35   5.99
#             Thursday           30   5.99
#             Tuesday            20   5.99
#             Wednesday          25   5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   3.99
# 1      Monday       Latte          15   5.99
# 2     Tuesday    Espresso          30   3.99
# 3     Tuesday       Latte          20   5.99
# 4   Wednesday    Espresso          35   3.99
# 5   Wednesday       Latte          25   5.99
# 6    Thursday    Espresso          40   3.99
# 7    Thursday       Latte          30   5.99
# 8      Friday    Espresso          45   3.99
# 9      Friday       Latte          35   5.99
# 10   Saturday    Espresso          45   3.99
# 11   Saturday       Latte          35   5.99
# 12     Sunday    Espresso          45   3.99
# 13     Sunday       Latte          35   5.99
