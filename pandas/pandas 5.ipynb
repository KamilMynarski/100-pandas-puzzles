# %%
import pandas as pd
import numpy as np

bios = pd.read_csv('./data/bios.csv')
bios['born_date'] = pd.to_datetime(bios['born_date'])
results = pd.read_parquet('./data/results.parquet')
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee['price'] = np.where(coffee['Coffee Type']=='Espresso',3.99,5.99)
coffee['revenue'] = coffee['price'] * coffee['Units Sold']

# %%
#pivot
pivot = coffee.pivot(columns='Coffee Type', index='Day',values='revenue')
pivot
pivot.loc['Monday','Latte']
pivot.sum()
pivot.sum(axis=1)
# Out:
# Day
# Friday       389.2
# Monday       189.6
# Saturday     389.2
# Sunday       389.2
# Thursday     339.3
# Tuesday      239.5
# Wednesday    289.4
# dtype: float64

# %%
# groupby plus counting
bios.groupby(bios['born_date'].dt.year)['name']
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name',ascending=False)
bios['month_born'] = bios['born_date'].dt.month
bios['year_born'] = bios['born_date'].dt.year
bios.groupby([bios['year_born'],bios['month_born']])['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 95       1857.0         5.0     1
# 96       1857.0         7.0     1
# 97       1857.0         8.0     1
# 98       1857.0         9.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]

# %%
#shift function
coffee['yestarday_revenue'] = coffee['revenue'].shift(2)
coffee['pct_change'] = coffee['revenue'] / coffee['yestarday_revenue'] * 100
#you can also shift backwards
# coffee['yestarday_revenue'] = coffee['revenue'].shift(-2)

coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yestarday_revenue
# 0      Monday    Espresso          25   3.99    99.75                NaN  \
# 1      Monday       Latte          15   5.99    89.85                NaN
# 2     Tuesday    Espresso          30   3.99   119.70              99.75
# 3     Tuesday       Latte          20   5.99   119.80              89.85
# 4   Wednesday    Espresso          35   3.99   139.65             119.70
# 5   Wednesday       Latte          25   5.99   149.75             119.80
# 6    Thursday    Espresso          40   3.99   159.60             139.65
# 7    Thursday       Latte          30   5.99   179.70             149.75
# 8      Friday    Espresso          45   3.99   179.55             159.60
# 9      Friday       Latte          35   5.99   209.65             179.70
# 10   Saturday    Espresso          45   3.99   179.55             179.55
# 11   Saturday       Latte          35   5.99   209.65             209.65
# 12     Sunday    Espresso          45   3.99   179.55             179.55
# 13     Sunday       Latte          35   5.99   209.65             209.65
#
#     pct_change
# 0          NaN
# 1          NaN
# 2   120.000000
# 3   133.333333
# 4   116.666667
# 5   125.000000
# 6   114.285714
# 7   120.000000
# 8   112.500000
# 9   116.666667
# 10  100.000000
# 11  100.000000
# 12  100.000000
# 13  100.000000

# %%
bios['height_rank'] = bios['height_cm'].rank()
bios.sort_values(['height_rank'],ascending=False)
# Out:
#         athlete_id                   name  born_date           born_city
# 89070        89782               Yao Ming 1980-09-12      Xuhui District  \
# 5781          5804         Tommy Burleson 1952-02-24           Crossnore
# 6978          7013        Arvydas Sabonis 1964-12-19              Kaunas
# 89075        89787         Roberto Dueñas 1975-11-01              Madrid
# 120266      122147           Zhang Zhaoxu 1987-11-18             Binzhou
# ...            ...                    ...        ...                 ...
# 145490      149217            Sin Ye-Chan 1995-06-13                 NaN
# 145491      149218          Matthew Wepke 1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country                         NOC
# 89070               Shanghai          CHN  People's Republic of China  \
# 5781          North Carolina          USA               United States
# 6978                  Kaunas          LTU      Lithuania Soviet Union
# 89075                 Madrid          ESP                       Spain
# 120266              Shandong          CHN  People's Republic of China
# ...                      ...          ...                         ...
# 145490                   NaN          NaN           Republic of Korea
# 145491                   NaN          NaN                     Jamaica
# 145492   Ciudad de La Habana          CUB                        Cuba
# 145493  Respublika Tatarstan          RUS                         ROC
# 145499       New South Wales          AUS                   Australia
#
#         height_cm  weight_kg   died_date  height_rank
# 89070       226.0      141.0         NaN     106651.0
# 5781        223.0      102.0         NaN     106649.5
# 6978        223.0      122.0         NaN     106649.5
# 89075       221.0      137.0         NaN     106647.0
# 120266      221.0      110.0         NaN     106647.0
# ...           ...        ...         ...          ...
# 145490        NaN        NaN         NaN          NaN
# 145491        NaN        NaN         NaN          NaN
# 145492        NaN        NaN  2019-11-24          NaN
# 145493        NaN        NaN         NaN          NaN
# 145499        NaN        NaN  2003-10-20          NaN
#
# [145500 rows x 11 columns]

# %%
bios['height_rank'] = bios['height_cm'].rank(method='min', ascending=False)

# %%
#cumulative sum
coffee.select_dtypes(['int','float']).cumsum()
#cumulative sum for one column
coffee['cumulative_revenue'] = coffee['revenue'].cumsum()
#cumulative sum over last 3 days
coffee['cumulative_revenue_3_days'] = coffee['revenue'].rolling(3).sum()

# %%
#to check package version
pd.__version__
# Out:
# '2.0.0'

# %%
# difference between numpy and pyarrow
results_numpy = pd.read_csv('./data/results.csv')
results_arrow = pd.read_csv('./data/results.csv', engine='pyarrow', dtype_backend='pyarrow')

# %%
#arrow is using strings instead of objects which is more memory efficient
#article to learn more https://datapythonista.me/blog/pandas-20-and-the-arrow-revolution-part-i
results_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        308408 non-null  string[pyarrow]
#  2   discipline  308408 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308408 non-null  string[pyarrow]
#  7   team        308408 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       308408 non-null  string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.4 MB

# %%
results_numpy['as'].str.contains('Kamil')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 308403    False
# 308404    False
# 308405    False
# 308406    False
# 308407    False
# Name: as, Length: 308408, dtype: bool

# %%
results_arrow['as'].str.contains('Kamil')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 308403    False
# 308404    False
# 308405    False
# 308406    False
# 308407    False
# Name: as, Length: 308408, dtype: bool[pyarrow]

# %%
filtered_bios = bios[(bios['born_region']== 'Slaskie') & (bios['height_cm'] > 180)]
filtered_bios
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[(bios['born_country']=='POL')|]
# Out:
#         athlete_id                  name  born_date            born_city
# 217            218     Kálmán Kirchmayer 1897-11-15              Rzeszów  \
# 503            505      Ursula Büschking 1941-09-23             Braniewo
# 515            517         Willi Gabriel 1939-09-24              Owiesno
# 1061          1068            Bożena Bąk 1966-01-28            Głubczyce
# 1062          1069  Magdalena Grzybowska 1978-11-22               Poznań
# ...            ...                   ...        ...                  ...
# 145032      148744           Marek Kania 1999-04-02    Warszawa (Warsaw)
# 145033      148745          Damian Żurek 1999-09-17  Tomaszów Mazowiecki
# 145035      148747     Kamila Stormowska 2000-04-12               Elbląg
# 145036      148748      Łukasz Kuczyński 1999-06-23              Sokolka
# 145037      148749      Michał Niewiński 2003-07-12            Białystok
#
#                 born_region born_country           NOC  height_cm  weight_kg
# 217            Podkarpackie          POL       Hungary        NaN        NaN  \
# 503     Warmińsko-Mazurskie          POL  West Germany      169.0       55.0
# 515            Dolnośląskie          POL  West Germany      165.0       63.0
# 1061               Opolskie          POL        Poland      180.0       70.0
# 1062          Wielkopolskie          POL        Poland      184.0       66.0
# ...                     ...          ...           ...        ...        ...
# 145032          Mazowieckie          POL        Poland        NaN        NaN
# 145033              Łódzkie          POL        Poland        NaN        NaN
# 145035  Warmińsko-Mazurskie          POL        Poland        NaN        NaN
# 145036            Podlaskie          POL        Poland        NaN        NaN
# 145037            Podlaskie          POL        Poland        NaN        NaN
#
#          died_date
# 217     1990-11-06
# 503            NaN
# 515            NaN
# 1061           NaN
# 1062           NaN
# ...            ...
# 145032         NaN
# 145033         NaN
# 145035         NaN
# 145036         NaN
# 145037         NaN
#
# [2942 rows x 10 columns]

# %%
#to randomly sample rows from a DataFrame
bios.sample(5)
# Out:
#         athlete_id             name  born_date           born_city  \
# 54643        55036   Zoran Petrović 1960-08-22  Beograd (Belgrade)
# 134504      137574    Randi Griffin 1988-09-02                Apex
# 24445        24634  Henning Enoksen 1935-09-26                 NaN
# 124550      126855        Kyu Maung 1970-08-11                 NaN
# 8767          8814  Miguel Amarista 1939-09-30                 NaN
#
#            born_region born_country         NOC  height_cm  weight_kg  \
# 54643          Beograd          SRB  Yugoslavia      203.0       98.0
# 134504  North Carolina          USA  Korea Team      165.0       58.0
# 24445              NaN          NaN     Denmark      178.0       70.0
# 124550             NaN          NaN     Myanmar      165.0       60.0
# 8767               NaN          NaN   Venezuela      173.0       63.0
#
#          died_date
# 54643          NaN
# 134504         NaN
# 24445   2016-09-25
# 124550         NaN
# 8767           NaN

# %%
#you can install packages in Jupyter Notebook using pip
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kamil\appdata\roaming\python\python311\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kamil\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kamil\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kamil\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
