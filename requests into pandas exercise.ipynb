# %%
import pandas as pd
import numpy as np
import os
import requests

# %%
def get_countries_by_language(language):
  url = 'https://restcountries.com/v3.1/lang/'+language
  try:
    response = requests.get(url)
    if response.status_code == 200:
      return pd.DataFrame(response.json())      
    elif response.status_code == 404:
      raise Exception(f"Language not found")
  except ZeroDivisionError:
    print("you can't divide by zero") 
  except Exception as e:
    print('error:', e)

# %%
def transform_contries_table(df):
  df['official'] = df['name'].apply(lambda x: x.get('official'))
  df = df[['official'] + [c for c in df.columns if c != 'official']]
  df['capital'] = df['capital'].apply(lambda x: x[0])
  df['currency'] = df['currencies'].apply(lambda x: list(x.values())[0]['name'])
  df=df.drop(['cca2','status','name','idd','tld','ccn3','currencies','latlng','car','flags','coatOfArms','capitalInfo','postalCode','timezones'],axis=1)
  return df

# %%
def save_into_file(df,language):
  #save file
  title = 'countries/' + language + '.csv'
  df.to_csv(title, index=False)

# %%
def extract_countries_into_csv(language):
  df = get_countries_by_language(language)
  df = transform_contries_table(df)
  save_into_file(df,language)

# %%
extract_countries_into_csv('Polish')

# %%
import requests

url = "https://example.com/api"

# Data can be form-encoded or raw bytes
data = {
    "field1": "value1",
    "field2": "value2"
}

# JSON body
json_body = {
    "name": "Alice",
    "age": 25
}

# Custom headers
headers = {
    "Authorization": "Bearer YOUR_ACCESS_TOKEN",
    "Custom-Header": "CustomValue"
}

# Example POST request sending both form data and JSON
response = requests.post(
    url,
    data=data,        # form-encoded data
    json=json_body,   # JSON body
    headers=headers
)

print("Status code:", response.status_code)
print("Response body:", response.text)
# Out:
# Status code: 403
# Response body: <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;example&#46;com&#47;api" on this server.<P>
# Reference&#32;&#35;18&#46;1dbbce17&#46;1765023915&#46;c0c19f
# <P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;1dbbce17&#46;1765023915&#46;c0c19f</P>
# </BODY>
# </HTML>

# %%
import requests

url = "https://example.com/api"

# GET request
response = requests.get(url, params={"q": "python"})
print(response.status_code, response.text)

# POST request
response = requests.post(url, json={"name": "Alice"})
print(response.status_code, response.text)
# Out:
# 404 <!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>
#
# 403 <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;example&#46;com&#47;api" on this server.<P>
# Reference&#32;&#35;18&#46;1dbbce17&#46;1765023980&#46;c115ce
# <P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;1dbbce17&#46;1765023980&#46;c115ce</P>
# </BODY>
# </HTML>
